# %% [markdown]
# # Supermart Grocery Sales - Exploratory Analysis
# This notebook demonstrates quick EDA steps.

# %%
import pandas as pd
pd.options.display.max_columns = 50
df = pd.read_csv('data/Supermart Grocery Sales - Retail Analytics Dataset.csv')

df.head()

# %%
# Run preprocessing and model steps from src
# !python src/eda.py
# !python src/preprocess.py
# !python src/model.py
